# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

#visualization
import matplotlib.pyplot as plt
import seaborn as sns

#data science - standard liberary
import pandas as pd
import numpy as np

#requests
import requests
import time
from pprint import pprint

#regression
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import scipy.stats as sts

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_sub=cities[0:10]
cities_sub
# Out:
# ['saskylakh',
#  'te anau',
#  'busselton',
#  'puerto ayora',
#  'barentsburg',
#  'hirado',
#  'atuona',
#  'bluff',
#  'jamestown',
#  'rikitea']

# %%
#init lists to hold parsed data
lats = []
longs = []
temps = []
feel_likes = []
humids = []
pressures = []
speeds = []
cities_found = []
cloudiness = []

for i in range(len(cities)):
    #get the city
    city = cities[i]
    
    #create the url
    units = "imperial"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&appid={weather_api_key}"
#     print(url)

    #make the request
    response = requests.get(url)
#     print(response.status_code)
    
     #error check
    if response.status_code == 200:
        data = response.json()
#         pprint(data)
        
        try:
            #extract the data
            lat = data["coord"]["lat"]
            long = data["coord"]["lon"]
            temp = data["main"]["temp"]
            feels_like = data["main"]["feels_like"]
            humidity = data["main"]["humidity"]
            pressure = data["main"]["pressure"]
            speed = data["wind"]["speed"]
            clouds = data["clouds"]["all"]
            city_name = data["name"]

            #save the data
            lats.append(lat)
            longs.append(long)
            temps.append(temp)
            feel_likes.append(feels_like)
            humids.append(humidity)
            pressures.append(pressure)
            speeds.append(speed)
            cloudiness.append(clouds)
            cities_found.append(city_name)
        except Exception as e:
            print(f"Through exception for city {city}: {e}")
    
    elif response.status_code == 404:
        print(f"Missing data in OpenWeatherAPI for {city}")
    else:
        print(response.status_code)
        print("Oh gosh darnit. The API is broken. Sad Face.")
        
        
        
    #print every 5
    if (i % 5 == 0):
        print(f"Got data for city index: {i} of {len(cities)}")
    
    
    #sleep for requests
    time.sleep(1)
# Out:
# Got data for city index: 0 of 604
# Missing data in OpenWeatherAPI for barentsburg
# Got data for city index: 5 of 604
# Got data for city index: 10 of 604
# Missing data in OpenWeatherAPI for khokholskiy
# Got data for city index: 15 of 604
# Missing data in OpenWeatherAPI for illoqqortoormiut
# Got data for city index: 20 of 604
# Missing data in OpenWeatherAPI for taolanaro
# Got data for city index: 25 of 604
# Got data for city index: 30 of 604
# Got data for city index: 35 of 604
# Missing data in OpenWeatherAPI for nizhneyansk
# Missing data in OpenWeatherAPI for mouzakion
# Got data for city index: 40 of 604
# Missing data in OpenWeatherAPI for ijaki
# Got data for city index: 45 of 604
# Got data for city index: 50 of 604
# Got data for city index: 55 of 604
# Got data for city index: 60 of 604
# Missing data in OpenWeatherAPI for attawapiskat
# Got data for city index: 65 of 604
# Got data for city index: 70 of 604
# Got data for city index: 75 of 604
# Got data for city index: 80 of 604
# Missing data in OpenWeatherAPI for mys shmidta
# Got data for city index: 85 of 604
# Got data for city index: 90 of 604
# Got data for city index: 95 of 604
# Got data for city index: 100 of 604
# Got data for city index: 105 of 604
# Got data for city index: 110 of 604
# Got data for city index: 115 of 604
# Missing data in OpenWeatherAPI for belushya guba
# Got data for city index: 120 of 604
# Got data for city index: 125 of 604
# Got data for city index: 130 of 604
# Got data for city index: 135 of 604
# Got data for city index: 140 of 604
# Missing data in OpenWeatherAPI for jiddah
# Got data for city index: 145 of 604
# Missing data in OpenWeatherAPI for tumannyy
# Missing data in OpenWeatherAPI for okandja
# Missing data in OpenWeatherAPI for alotau
# Got data for city index: 150 of 604
# Missing data in OpenWeatherAPI for tsihombe
# Missing data in OpenWeatherAPI for barawe
# Got data for city index: 155 of 604
# Got data for city index: 160 of 604
# Got data for city index: 165 of 604
# Got data for city index: 170 of 604
# Got data for city index: 175 of 604
# Missing data in OpenWeatherAPI for falealupo
# Got data for city index: 180 of 604
# Got data for city index: 185 of 604
# Got data for city index: 190 of 604
# Got data for city index: 195 of 604
# Missing data in OpenWeatherAPI for saryshagan
# Got data for city index: 200 of 604
# Got data for city index: 205 of 604
# Missing data in OpenWeatherAPI for jabiru
# Got data for city index: 210 of 604
# Got data for city index: 215 of 604
# Got data for city index: 220 of 604
# Missing data in OpenWeatherAPI for ksenyevka
# Got data for city index: 225 of 604
# Got data for city index: 230 of 604
# Missing data in OpenWeatherAPI for bur gabo
# Got data for city index: 235 of 604
# Got data for city index: 240 of 604
# Missing data in OpenWeatherAPI for grand centre
# Got data for city index: 245 of 604
# Missing data in OpenWeatherAPI for saleaula
# Got data for city index: 250 of 604
# Got data for city index: 255 of 604
# Got data for city index: 260 of 604
# Got data for city index: 265 of 604
# Missing data in OpenWeatherAPI for kazalinsk
# Missing data in OpenWeatherAPI for lolua
# Got data for city index: 270 of 604
# Missing data in OpenWeatherAPI for chikoy
# Missing data in OpenWeatherAPI for cumaribo
# Got data for city index: 275 of 604
# Got data for city index: 280 of 604
# Got data for city index: 285 of 604
# Got data for city index: 290 of 604
# Missing data in OpenWeatherAPI for malwan
# Got data for city index: 295 of 604
# Got data for city index: 300 of 604
# Got data for city index: 305 of 604
# Got data for city index: 310 of 604
# Missing data in OpenWeatherAPI for ngukurr
# Got data for city index: 315 of 604
# Got data for city index: 320 of 604
# Got data for city index: 325 of 604
# Missing data in OpenWeatherAPI for mahaicony
# Got data for city index: 330 of 604
# Missing data in OpenWeatherAPI for amderma
# Got data for city index: 335 of 604
# Got data for city index: 340 of 604
# Got data for city index: 345 of 604
# Missing data in OpenWeatherAPI for nguiu
# Got data for city index: 350 of 604
# Got data for city index: 355 of 604
# Got data for city index: 360 of 604
# Got data for city index: 365 of 604
# Missing data in OpenWeatherAPI for grand river south east
# Missing data in OpenWeatherAPI for taburi
# Got data for city index: 370 of 604
# Got data for city index: 375 of 604
# Missing data in OpenWeatherAPI for cam pha
# Got data for city index: 380 of 604
# Got data for city index: 385 of 604
# Got data for city index: 390 of 604
# Got data for city index: 395 of 604
# Got data for city index: 400 of 604
# Got data for city index: 405 of 604
# Got data for city index: 410 of 604
# Got data for city index: 415 of 604
# Missing data in OpenWeatherAPI for samusu
# Got data for city index: 420 of 604
# Missing data in OpenWeatherAPI for vaitupu
# Got data for city index: 425 of 604
# Missing data in OpenWeatherAPI for dipkarpaz
# Got data for city index: 430 of 604
# Got data for city index: 435 of 604
# Got data for city index: 440 of 604
# Got data for city index: 445 of 604
# Got data for city index: 450 of 604
# Missing data in OpenWeatherAPI for tiruvottiyur
# Missing data in OpenWeatherAPI for louisbourg
# Got data for city index: 455 of 604
# Got data for city index: 460 of 604
# Got data for city index: 465 of 604
# Got data for city index: 470 of 604
# Got data for city index: 475 of 604
# Missing data in OpenWeatherAPI for sentyabrskiy
# Got data for city index: 480 of 604
# Missing data in OpenWeatherAPI for warqla
# Got data for city index: 485 of 604
# Got data for city index: 490 of 604
# Missing data in OpenWeatherAPI for maimon
# Missing data in OpenWeatherAPI for kadykchan
# Missing data in OpenWeatherAPI for dinsor
# Got data for city index: 495 of 604
# Got data for city index: 500 of 604
# Got data for city index: 505 of 604
# Got data for city index: 510 of 604
# Got data for city index: 515 of 604
# Got data for city index: 520 of 604
# Got data for city index: 525 of 604
# Missing data in OpenWeatherAPI for urdzhar
# Got data for city index: 530 of 604
# Got data for city index: 535 of 604
# Got data for city index: 540 of 604
# Got data for city index: 545 of 604
# Got data for city index: 550 of 604
# Missing data in OpenWeatherAPI for ruatoria
# Got data for city index: 555 of 604
# Got data for city index: 560 of 604
# Got data for city index: 565 of 604
# Missing data in OpenWeatherAPI for balimo
# Got data for city index: 570 of 604
# Got data for city index: 575 of 604
# Got data for city index: 580 of 604
# Got data for city index: 585 of 604
# Missing data in OpenWeatherAPI for mau aima
# Got data for city index: 590 of 604
# Missing data in OpenWeatherAPI for marcona
# Got data for city index: 595 of 604
# Got data for city index: 600 of 604

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# make the dataframe
df = pd.DataFrame()
df["City"] = cities_found
df["Latitude"] = lats
df["Longitude"] = longs
df["Temperature"] = temps
df["Feels Like"] = feel_likes
df["Humidity"] = humids
df["Pressure"] = pressures
df["Wind Speed"] = speeds
df["Cloudiness"] = cloudiness

df.head()
# Out:
#            City  Latitude  Longitude  Temperature  Feels Like  Humidity  \
# 0     Saskylakh     71.92     114.08        -7.91      -22.68        86
# 1       Te Anau    -45.42     167.72        57.13       52.84        55
# 2     Busselton    -33.65     115.33        60.37       53.62        82
# 3  Puerto Ayora     -0.74     -90.35        69.01       70.34        83
# 4        Hirado     33.36     129.55        56.39       45.70        47
#
#    Pressure  Wind Speed  Cloudiness
# 0      1008       14.38          13
# 1      1018        4.05          92
# 2       996       14.65          97
# 3      1012        5.99          11
# 4      1022       13.87          20

# %%
#save as CVS fiel for later use
df.to_csv(output_data_file,index=False)
